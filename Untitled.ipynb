# %%
import pandas as pd

# %%
pd.read_csv('sentiments.csv',index_col=False).sents.tolist()
# Out:
# ['Physiology - Static - Positive',
#  'Living Space - Static - Positive',
#  'Mobility - Static - Positive',
#  'Health - Static - Positive',
#  'Safety - Static - Positive',
#  'Security - Static - Positive',
#  'Intimacy - Static - Positive',
#  'Aesthetics - Static - Positive',
#  'Knowledge - Static - Positive',
#  'Innovation - Static - Positive',
#  'Community - Static - Positive',
#  'Society - Static - Positive',
#  'Recreation - Static - Positive',
#  'Relaxation - Static - Positive',
#  'Creativity - Static - Positive',
#  'Productivity - Static - Positive',
#  'Belonging - Static - Positive',
#  'Recognition - Static - Positive',
#  'Autonomy - Static - Positive',
#  'Liberty - Static - Positive',
#  'Physiology - Trend - Positive',
#  'Living Space - Trend - Positive',
#  'Mobility - Trend - Positive',
#  'Health - Trend - Positive',
#  'Safety - Trend - Positive',
#  'Security - Trend - Positive',
#  'Intimacy - Trend - Positive',
#  'Aesthetics - Trend - Positive',
# ...

# %%
df.sents.tolist()
# Out:
# ['Physiology - Static - Positive',
#  'Living Space - Static - Positive',
#  'Mobility - Static - Positive',
#  'Health - Static - Positive',
#  'Safety - Static - Positive',
#  'Security - Static - Positive',
#  'Intimacy - Static - Positive',
#  'Aesthetics - Static - Positive',
#  'Knowledge - Static - Positive',
#  'Innovation - Static - Positive',
#  'Community - Static - Positive',
#  'Society - Static - Positive',
#  'Recreation - Static - Positive',
#  'Relaxation - Static - Positive',
#  'Creativity - Static - Positive',
#  'Productivity - Static - Positive',
#  'Belonging - Static - Positive',
#  'Recognition - Static - Positive',
#  'Autonomy - Static - Positive',
#  'Liberty - Static - Positive',
#  'Physiology - Trend - Positive',
#  'Living Space - Trend - Positive',
#  'Mobility - Trend - Positive',
#  'Health - Trend - Positive',
#  'Safety - Trend - Positive',
#  'Security - Trend - Positive',
#  'Intimacy - Trend - Positive',
#  'Aesthetics - Trend - Positive',
# ...
